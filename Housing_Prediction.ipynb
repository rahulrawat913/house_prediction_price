# %%
# Importing Libararies

import numpy as np
import pandas as pd
import re
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
from datetime import datetime

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,PolynomialFeatures
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
housing_data=pd.read_csv("train.csv")
housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ### Data Pre-Processing

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#find colmns that does not add any values -  removing columns that has more than 50% of null data 

column_with_nulls=housing_data.columns[100*(housing_data.isnull().sum()/len(housing_data.index))>90]
column_with_nulls
housing_data.drop(column_with_nulls,axis=1,inplace=True)
housing_data.drop('Id',axis=1,inplace=True)

# %%
pd.options.display.max_rows = 4000

# %%
100*(housing_data.isnull().sum()/len(housing_data.index))
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinSF1        0.000000
# BsmtFinType2      2.602740
# ...

# %% [markdown]
# Lets Visualize the Data

# %%
#lets collect all numeric columns and plot the maps against target 
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

housing_numeric_columns = housing_data.select_dtypes(include=numerics)
housing_numeric_columns
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# 5             50         85.0    14115            5            5       1993
# 6             20         75.0    10084            8            5       2004
# 7             60          NaN    10382            7            6       1973
# 8             50         51.0     6120            7            5       1931
# 9            190         50.0     7420            5            6       1939
# 10            20         70.0    11200            5            5       1965
# ...

# %% [markdown]
# Understanding Data

# %%
#Type of road access to property
housing_data['Street'].astype('category').value_counts()
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64

# %%
#General shape of property
housing_data['LotShape'].astype('category').value_counts()
# Out:
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64

# %%
#Type of utilities available
housing_data['Utilities'].astype('category').value_counts()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64

# %%
#Type of utilities available
housing_data['Neighborhood'].astype('category').value_counts()
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
#Type of utilities available
housing_data['BldgType'].astype('category').value_counts()
# Out:
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64

# %%
#Type of utilities available
housing_data['HouseStyle'].astype('category').value_counts()
# Out:
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: count, dtype: int64

# %%
#Type of Roof
housing_data['RoofStyle'].astype('category').value_counts()
# Out:
# RoofStyle
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: count, dtype: int64

# %%
# poolArea
sns.distplot(housing_data['WoodDeckSF'])
plt.show()

# %%
# poolArea
sns.distplot(housing_data['SalePrice'])
plt.show()

# %%
# poolArea
sns.distplot(housing_data['LotArea'])
plt.show()

# %%
# poolArea
sns.distplot(housing_data['YearBuilt'])
plt.show()

# %%
# all numeric (float and int) variables in the dataset
housing_data_numeric = housing_data.select_dtypes(include=['float64', 'int64'])
housing_data_numeric.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 0          2003       196.0         706           0  ...           0
# 1          1976         0.0         978           0  ...         298
# 2          2002       162.0         486           0  ...           0
# 3          1970         0.0         216           0  ...           0
# 4          2000       350.0         655           0  ...         192
#
#    OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %% [markdown]
# lets Read Co-relation Matrix to understand relation between columns

# %%
# correlation matrix
cor = housing_data_numeric.corr()
cor
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.386347 -0.139781     0.032628    -0.059316
# LotFrontage     -0.386347     1.000000  0.426095     0.251646    -0.059213
# LotArea         -0.139781     0.426095  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.251646  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.059213 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.123349  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.088866  0.013788     0.550684     0.073741
# MasVnrArea       0.022936     0.193458  0.104160     0.411876    -0.128101
# BsmtFinSF1      -0.069836     0.233633  0.214103     0.239666    -0.046231
# BsmtFinSF2      -0.065649     0.049900  0.111170    -0.059119     0.040229
# BsmtUnfSF       -0.140759     0.132644 -0.002618     0.308159    -0.136841
# ...

# %% [markdown]
# Corelation shows that below variables are strongly co-related to Sales Prices Variable
#
# Overall Quality - Rates the overall material and finish of the house
#
#
# YearBuilt - Original construction date
#
#
# YearRemodAdd -Remodel date (same as construction date if no remodeling or additions)
#
#
# MasVnrArea - Masonry veneer area in square feet

# %% [markdown]
# # Data Cleaning

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
# creating dummy variables for categorical variables
housing_categ = X.select_dtypes(include=['object'])
cars_categorical.head()
